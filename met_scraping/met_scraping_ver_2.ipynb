# %% [markdown]
# # Met scraping code
#
# what you will need to adjust before running:
# - f_path : is path to the met txt database
# - output_folder : path to where the images should be saved (big parquet file will be saved into wd)
#
# have fun! 🌱

# %% [markdown]
# ## Setting up scraping environment

# %%
import os
import time
import random
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Scraping

# %% [markdown]
# ### Setting up db

# %%
# reading in the met txt
f_path = ""
data = pd.read_csv(f_path)
# for images and parquet file of urls
output_folder = ""

# %%
#getting just id and url
cols = [4, 47]
scrape_dt = data[data.columns[cols]]
scrape_dt["im_link"] = None

# %% [markdown]
# ### Looping through the database, scraping and saving images
#
# the codes makes batches of 15 rows (this can be changed by assigning different value to batch_size)
# by batch
# - it scrapes the image url associated with the id in the met txt catalouge. Pastes the image url into the dataframe
# - saves the images into the predefied output_folder by ID + .jpg
# - writes the dataframe into a parquet file so it will not be lost if the process crashes
# - sets a random sleeper before continuing to the next batch. This ensures that we don't overstep the allowed query maximum of the met site
#
# code was tested on the first 2000 rows

# %%
# must include the columns: 'Link Resource', 'im_link', and 'Object ID'


os.makedirs(output_folder, exist_ok=True)
big_parquet_file = "complete_data.parquet"

batch_size = 15
total_rows = len(scrape_dt)

for start in range(0, total_rows, batch_size):
    end = min(start + batch_size, total_rows)
    print(f"Processing rows {start} to {end - 1}...")

    # --- Scraping Phase ---
    for index in range(start, end):
        url = scrape_dt.loc[index, "Link Resource"]
        try:
            response = requests.get(url)
            response.raise_for_status()  # Throws error on bad responses
        except requests.RequestException as e:
            print(f"Request failed for {url}: {e}")
            scrape_dt.loc[index, "im_link"] = np.nan
            continue

        soup = BeautifulSoup(response.text, "html.parser")
        elements = soup.select(
            "img#artwork__image.artwork__image.js-artwork__image.gtm__artwork__image"
        )
        if elements:
            image_link = elements[0].get("src", np.nan)
            scrape_dt.loc[index, "im_link"] = image_link
            print(f"Row {index}: Found image link: {image_link}")
        else:
            print(f"Row {index}: No image found for {url}. Setting to NA.")
            scrape_dt.loc[index, "im_link"] = np.nan

    # --- Image Downloading Phase ---
    for index in range(start, end):
        image_url = scrape_dt.loc[index, "im_link"]
        image_id = scrape_dt.loc[index, "Object ID"]
        if not isinstance(image_url, str) or image_url.lower() in ["nan", "none"]:
            print(
                f"Skipping row {index}: No valid image link for Object ID {image_id}."
            )
            continue

        image_filename = os.path.join(output_folder, f"{image_id}.jpg")
        try:
            response = requests.get(image_url, stream=True)
            response.raise_for_status()
            with open(image_filename, "wb") as file:
                for chunk in response.iter_content(1024):  # Download in 1KB chunks
                    file.write(chunk)
            print(f"Downloaded image for Object ID {image_id} to {image_filename}")
        except requests.RequestException as e:
            print(
                f"Failed to download image for Object ID {image_id} from {image_url}: {e}"
            )

    # --- Save the Entire DataFrame to a Single Parquet File ---
    scrape_dt.to_parquet(big_parquet_file, index=False)
    print(f"Updated the complete Parquet file: {big_parquet_file}")

    # --- Take a Random Snooze Before Next Batch ---
    sleep_time = random.uniform(1, 5)  # Sleep between 1 and 5 seconds
    print(
        f"Batch {start} to {end - 1} complete. Sleeping for {sleep_time:.2f} seconds...\n"
    )
    time.sleep(sleep_time)
# Out:
# Processing rows 0 to 14...
# Row 0: No image found for http://www.metmuseum.org/art/collection/search/1. Setting to NA.
# Row 1: No image found for http://www.metmuseum.org/art/collection/search/2. Setting to NA.
# Row 2: No image found for http://www.metmuseum.org/art/collection/search/3. Setting to NA.
# Row 3: No image found for http://www.metmuseum.org/art/collection/search/4. Setting to NA.
# Row 4: No image found for http://www.metmuseum.org/art/collection/search/5. Setting to NA.
# Row 5: No image found for http://www.metmuseum.org/art/collection/search/6. Setting to NA.
# Row 6: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/7/20225/restricted
# Row 7: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/8/20226/restricted
# Row 8: No image found for http://www.metmuseum.org/art/collection/search/9. Setting to NA.
# Row 9: No image found for http://www.metmuseum.org/art/collection/search/10. Setting to NA.
# Row 10: No image found for http://www.metmuseum.org/art/collection/search/11. Setting to NA.
# Row 11: No image found for http://www.metmuseum.org/art/collection/search/12. Setting to NA.
# Row 12: No image found for http://www.metmuseum.org/art/collection/search/13. Setting to NA.
# Row 13: No image found for http://www.metmuseum.org/art/collection/search/14. Setting to NA.
# Row 14: No image found for http://www.metmuseum.org/art/collection/search/15. Setting to NA.
# Skipping row 0: No valid image link for Object ID 1.
# Skipping row 1: No valid image link for Object ID 2.
# Skipping row 2: No valid image link for Object ID 3.
# Skipping row 3: No valid image link for Object ID 4.
# Skipping row 4: No valid image link for Object ID 5.
# Skipping row 5: No valid image link for Object ID 6.
# Downloaded image for Object ID 7 to /Users/zoeungvari/databases/met_images/7.jpg
# Downloaded image for Object ID 8 to /Users/zoeungvari/databases/met_images/8.jpg
# Skipping row 8: No valid image link for Object ID 9.
# Skipping row 9: No valid image link for Object ID 10.
# Skipping row 10: No valid image link for Object ID 11.
# Skipping row 11: No valid image link for Object ID 12.
# Skipping row 12: No valid image link for Object ID 13.
# Skipping row 13: No valid image link for Object ID 14.
# Skipping row 14: No valid image link for Object ID 15.
# Updated the complete Parquet file: complete_data.parquet
# Batch 0 to 14 complete. Sleeping for 1.32 seconds...
#
# Processing rows 15 to 29...
# Row 15: No image found for http://www.metmuseum.org/art/collection/search/16. Setting to NA.
# Row 16: No image found for http://www.metmuseum.org/art/collection/search/17. Setting to NA.
# Row 17: No image found for http://www.metmuseum.org/art/collection/search/18. Setting to NA.
# Row 18: No image found for http://www.metmuseum.org/art/collection/search/19. Setting to NA.
# Row 19: No image found for http://www.metmuseum.org/art/collection/search/20. Setting to NA.
# Row 20: No image found for http://www.metmuseum.org/art/collection/search/21. Setting to NA.
# Row 21: No image found for http://www.metmuseum.org/art/collection/search/22. Setting to NA.
# Row 22: No image found for http://www.metmuseum.org/art/collection/search/23. Setting to NA.
# Row 23: No image found for http://www.metmuseum.org/art/collection/search/24. Setting to NA.
# Row 24: No image found for http://www.metmuseum.org/art/collection/search/25. Setting to NA.
# Row 25: No image found for http://www.metmuseum.org/art/collection/search/26. Setting to NA.
# Row 26: No image found for http://www.metmuseum.org/art/collection/search/27. Setting to NA.
# Row 27: No image found for http://www.metmuseum.org/art/collection/search/28. Setting to NA.
# Row 28: No image found for http://www.metmuseum.org/art/collection/search/29. Setting to NA.
# Row 29: No image found for http://www.metmuseum.org/art/collection/search/30. Setting to NA.
# Skipping row 15: No valid image link for Object ID 16.
# Skipping row 16: No valid image link for Object ID 17.
# Skipping row 17: No valid image link for Object ID 18.
# Skipping row 18: No valid image link for Object ID 19.
# Skipping row 19: No valid image link for Object ID 20.
# Skipping row 20: No valid image link for Object ID 21.
# Skipping row 21: No valid image link for Object ID 22.
# Skipping row 22: No valid image link for Object ID 23.
# Skipping row 23: No valid image link for Object ID 24.
# Skipping row 24: No valid image link for Object ID 25.
# Skipping row 25: No valid image link for Object ID 26.
# Skipping row 26: No valid image link for Object ID 27.
# Skipping row 27: No valid image link for Object ID 28.
# Skipping row 28: No valid image link for Object ID 29.
# Skipping row 29: No valid image link for Object ID 30.
# Updated the complete Parquet file: complete_data.parquet
# Batch 15 to 29 complete. Sleeping for 2.60 seconds...
#
# Processing rows 30 to 44...
# Row 30: No image found for http://www.metmuseum.org/art/collection/search/31. Setting to NA.
# Row 31: No image found for http://www.metmuseum.org/art/collection/search/32. Setting to NA.
# Row 32: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/33/13579/restricted
# Row 33: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/34/20602/main-image
# Row 34: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/35/35232/restricted
# Row 35: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/36/27067/restricted
# Row 36: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/37/46007/main-image
# Row 37: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/38/46008/main-image
# Row 38: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/39/4360/main-image
# Row 39: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/40/17983/main-image
# Row 40: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/41/18461/main-image
# Row 41: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/42/13285/main-image
# Row 42: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/43/13286/main-image
# Row 43: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/44/2509/main-image
# Row 44: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/45/2510/main-image
# Skipping row 30: No valid image link for Object ID 31.
# Skipping row 31: No valid image link for Object ID 32.
# Downloaded image for Object ID 33 to /Users/zoeungvari/databases/met_images/33.jpg
# Downloaded image for Object ID 34 to /Users/zoeungvari/databases/met_images/34.jpg
# Downloaded image for Object ID 35 to /Users/zoeungvari/databases/met_images/35.jpg
# Downloaded image for Object ID 36 to /Users/zoeungvari/databases/met_images/36.jpg
# Downloaded image for Object ID 37 to /Users/zoeungvari/databases/met_images/37.jpg
# Downloaded image for Object ID 38 to /Users/zoeungvari/databases/met_images/38.jpg
# Downloaded image for Object ID 39 to /Users/zoeungvari/databases/met_images/39.jpg
# Downloaded image for Object ID 40 to /Users/zoeungvari/databases/met_images/40.jpg
# Downloaded image for Object ID 41 to /Users/zoeungvari/databases/met_images/41.jpg
# Downloaded image for Object ID 42 to /Users/zoeungvari/databases/met_images/42.jpg
# Downloaded image for Object ID 43 to /Users/zoeungvari/databases/met_images/43.jpg
# Downloaded image for Object ID 44 to /Users/zoeungvari/databases/met_images/44.jpg
# Downloaded image for Object ID 45 to /Users/zoeungvari/databases/met_images/45.jpg
# Updated the complete Parquet file: complete_data.parquet
# Batch 30 to 44 complete. Sleeping for 2.39 seconds...
#
# Processing rows 45 to 59...
# Row 45: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/46/2512/main-image
# Row 46: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/47/2513/main-image
# Row 47: No image found for http://www.metmuseum.org/art/collection/search/48. Setting to NA.
# Row 48: No image found for http://www.metmuseum.org/art/collection/search/49. Setting to NA.
# Row 49: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/50/2521/main-image
# Row 50: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/51/2522/main-image
# Row 51: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/52/2514/main-image
# Row 52: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/53/2515/main-image
# Row 53: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/56/2516/main-image
# Row 54: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/57/2517/main-image
# Row 55: No image found for http://www.metmuseum.org/art/collection/search/58. Setting to NA.
# Row 56: No image found for http://www.metmuseum.org/art/collection/search/59. Setting to NA.
# Row 57: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/62/4925/main-image
# Row 58: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/63/4927/main-image
# Row 59: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/64/5055/main-image
# Downloaded image for Object ID 46 to /Users/zoeungvari/databases/met_images/46.jpg
# Downloaded image for Object ID 47 to /Users/zoeungvari/databases/met_images/47.jpg
# Skipping row 47: No valid image link for Object ID 48.
# Skipping row 48: No valid image link for Object ID 49.
# Downloaded image for Object ID 50 to /Users/zoeungvari/databases/met_images/50.jpg
# Downloaded image for Object ID 51 to /Users/zoeungvari/databases/met_images/51.jpg
# Downloaded image for Object ID 52 to /Users/zoeungvari/databases/met_images/52.jpg
# Downloaded image for Object ID 53 to /Users/zoeungvari/databases/met_images/53.jpg
# Downloaded image for Object ID 56 to /Users/zoeungvari/databases/met_images/56.jpg
# Downloaded image for Object ID 57 to /Users/zoeungvari/databases/met_images/57.jpg
# Skipping row 55: No valid image link for Object ID 58.
# Skipping row 56: No valid image link for Object ID 59.
# Downloaded image for Object ID 62 to /Users/zoeungvari/databases/met_images/62.jpg
# Downloaded image for Object ID 63 to /Users/zoeungvari/databases/met_images/63.jpg
# Downloaded image for Object ID 64 to /Users/zoeungvari/databases/met_images/64.jpg
# Updated the complete Parquet file: complete_data.parquet
# Batch 45 to 59 complete. Sleeping for 4.40 seconds...
#
# Processing rows 60 to 74...
# Row 60: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/65/5056/main-image
# Row 61: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/68/7309/main-image
# Row 62: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/69/7310/main-image
# Row 63: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/70/8657/main-image
# Row 64: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/71/8658/main-image
# Row 65: No image found for http://www.metmuseum.org/art/collection/search/72. Setting to NA.
# Row 66: No image found for http://www.metmuseum.org/art/collection/search/73. Setting to NA.
# Row 67: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/74/9218/main-image
# Row 68: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/75/9219/main-image
# Row 69: No image found for http://www.metmuseum.org/art/collection/search/76. Setting to NA.
# Row 70: No image found for http://www.metmuseum.org/art/collection/search/77. Setting to NA.
# Row 71: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/78/9357/main-image
# Row 72: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/79/9358/main-image
# Row 73: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/80/9822/main-image
# Row 74: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/81/9823/main-image
# Downloaded image for Object ID 65 to /Users/zoeungvari/databases/met_images/65.jpg
# Downloaded image for Object ID 68 to /Users/zoeungvari/databases/met_images/68.jpg
# Downloaded image for Object ID 69 to /Users/zoeungvari/databases/met_images/69.jpg
# Downloaded image for Object ID 70 to /Users/zoeungvari/databases/met_images/70.jpg
# Downloaded image for Object ID 71 to /Users/zoeungvari/databases/met_images/71.jpg
# Skipping row 65: No valid image link for Object ID 72.
# Skipping row 66: No valid image link for Object ID 73.
# Downloaded image for Object ID 74 to /Users/zoeungvari/databases/met_images/74.jpg
# Downloaded image for Object ID 75 to /Users/zoeungvari/databases/met_images/75.jpg
# Skipping row 69: No valid image link for Object ID 76.
# Skipping row 70: No valid image link for Object ID 77.
# Downloaded image for Object ID 78 to /Users/zoeungvari/databases/met_images/78.jpg
# Downloaded image for Object ID 79 to /Users/zoeungvari/databases/met_images/79.jpg
# Downloaded image for Object ID 80 to /Users/zoeungvari/databases/met_images/80.jpg
# Downloaded image for Object ID 81 to /Users/zoeungvari/databases/met_images/81.jpg
# Updated the complete Parquet file: complete_data.parquet
# Batch 60 to 74 complete. Sleeping for 4.05 seconds...
#
# Processing rows 75 to 89...
# Row 75: No image found for http://www.metmuseum.org/art/collection/search/84. Setting to NA.
# Row 76: No image found for http://www.metmuseum.org/art/collection/search/85. Setting to NA.
# Row 77: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/86/10351/main-image
# Row 78: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/87/10352/main-image
# Row 79: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/88/10354/main-image
# Row 80: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/89/10355/main-image
# Row 81: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/90/10371/main-image
# Row 82: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/91/10372/main-image
# Row 83: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/92/1857147/main-image
# Row 84: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/93/17894/main-image
# Row 85: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/94/18803/main-image
# Row 86: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/95/18804/main-image
# Row 87: No image found for http://www.metmuseum.org/art/collection/search/96. Setting to NA.
# Row 88: No image found for http://www.metmuseum.org/art/collection/search/97. Setting to NA.
# Row 89: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/98/19116/main-image
# Skipping row 75: No valid image link for Object ID 84.
# Skipping row 76: No valid image link for Object ID 85.
# Downloaded image for Object ID 86 to /Users/zoeungvari/databases/met_images/86.jpg
# Downloaded image for Object ID 87 to /Users/zoeungvari/databases/met_images/87.jpg
# Downloaded image for Object ID 88 to /Users/zoeungvari/databases/met_images/88.jpg
# Downloaded image for Object ID 89 to /Users/zoeungvari/databases/met_images/89.jpg
# Downloaded image for Object ID 90 to /Users/zoeungvari/databases/met_images/90.jpg
# Downloaded image for Object ID 91 to /Users/zoeungvari/databases/met_images/91.jpg
# Downloaded image for Object ID 92 to /Users/zoeungvari/databases/met_images/92.jpg
# Downloaded image for Object ID 93 to /Users/zoeungvari/databases/met_images/93.jpg
# Downloaded image for Object ID 94 to /Users/zoeungvari/databases/met_images/94.jpg
# Downloaded image for Object ID 95 to /Users/zoeungvari/databases/met_images/95.jpg
# Skipping row 87: No valid image link for Object ID 96.
# Skipping row 88: No valid image link for Object ID 97.
# Downloaded image for Object ID 98 to /Users/zoeungvari/databases/met_images/98.jpg
# Updated the complete Parquet file: complete_data.parquet
# Batch 75 to 89 complete. Sleeping for 3.94 seconds...
#
# Processing rows 90 to 104...
# Row 90: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/99/19117/main-image
# Row 91: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/100/18904/main-image
# Row 92: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/101/18905/main-image
# Row 93: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/102/20769/main-image
# Row 94: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/103/20771/main-image
# Row 95: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/104/15342/main-image
# Row 96: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/105/15343/main-image
# Row 97: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/106/15770/main-image
# Row 98: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/107/15771/main-image
# Row 99: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/108/16448/main-image
# Row 100: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/109/16449/main-image
# Row 101: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/110/10374/main-image
# Row 102: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/111/10375/main-image
# Row 103: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/112/21562/main-image
# Row 104: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/113/21563/main-image
# Downloaded image for Object ID 99 to /Users/zoeungvari/databases/met_images/99.jpg
# Downloaded image for Object ID 100 to /Users/zoeungvari/databases/met_images/100.jpg
# Downloaded image for Object ID 101 to /Users/zoeungvari/databases/met_images/101.jpg
# Downloaded image for Object ID 102 to /Users/zoeungvari/databases/met_images/102.jpg
# Downloaded image for Object ID 103 to /Users/zoeungvari/databases/met_images/103.jpg
# Downloaded image for Object ID 104 to /Users/zoeungvari/databases/met_images/104.jpg
# Downloaded image for Object ID 105 to /Users/zoeungvari/databases/met_images/105.jpg
# Downloaded image for Object ID 106 to /Users/zoeungvari/databases/met_images/106.jpg
# Downloaded image for Object ID 107 to /Users/zoeungvari/databases/met_images/107.jpg
# Downloaded image for Object ID 108 to /Users/zoeungvari/databases/met_images/108.jpg
# Downloaded image for Object ID 109 to /Users/zoeungvari/databases/met_images/109.jpg
# Downloaded image for Object ID 110 to /Users/zoeungvari/databases/met_images/110.jpg
# Downloaded image for Object ID 111 to /Users/zoeungvari/databases/met_images/111.jpg
# Downloaded image for Object ID 112 to /Users/zoeungvari/databases/met_images/112.jpg
# Downloaded image for Object ID 113 to /Users/zoeungvari/databases/met_images/113.jpg
# Updated the complete Parquet file: complete_data.parquet
# Batch 90 to 104 complete. Sleeping for 3.44 seconds...
#
# Processing rows 105 to 119...
# Row 105: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/114/7315/main-image
# Row 106: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/115/7316/main-image
# Row 107: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/116/19512/main-image
# Row 108: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/117/19513/main-image
# Row 109: No image found for http://www.metmuseum.org/art/collection/search/118. Setting to NA.
# Row 110: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/119/20768/main-image
# Row 111: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/120/41827/restricted
# Row 112: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/121/20269/restricted
# Row 113: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/122/13643/main-image
# Row 114: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/123/13644/main-image
# Row 115: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/124/9559/main-image
# Row 116: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/125/9561/main-image
# Row 117: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/126/17804/main-image
# Row 118: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/127/17805/main-image
# Row 119: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/128/17806/main-image
# Downloaded image for Object ID 114 to /Users/zoeungvari/databases/met_images/114.jpg
# Downloaded image for Object ID 115 to /Users/zoeungvari/databases/met_images/115.jpg
# Downloaded image for Object ID 116 to /Users/zoeungvari/databases/met_images/116.jpg
# Downloaded image for Object ID 117 to /Users/zoeungvari/databases/met_images/117.jpg
# Skipping row 109: No valid image link for Object ID 118.
# Downloaded image for Object ID 119 to /Users/zoeungvari/databases/met_images/119.jpg
# Downloaded image for Object ID 120 to /Users/zoeungvari/databases/met_images/120.jpg
# Downloaded image for Object ID 121 to /Users/zoeungvari/databases/met_images/121.jpg
# Downloaded image for Object ID 122 to /Users/zoeungvari/databases/met_images/122.jpg
# Downloaded image for Object ID 123 to /Users/zoeungvari/databases/met_images/123.jpg
# Downloaded image for Object ID 124 to /Users/zoeungvari/databases/met_images/124.jpg
# Downloaded image for Object ID 125 to /Users/zoeungvari/databases/met_images/125.jpg
# Downloaded image for Object ID 126 to /Users/zoeungvari/databases/met_images/126.jpg
# Downloaded image for Object ID 127 to /Users/zoeungvari/databases/met_images/127.jpg
# Downloaded image for Object ID 128 to /Users/zoeungvari/databases/met_images/128.jpg
# Updated the complete Parquet file: complete_data.parquet
# Batch 105 to 119 complete. Sleeping for 3.95 seconds...
#
# Processing rows 120 to 134...
# Row 120: No image found for http://www.metmuseum.org/art/collection/search/129. Setting to NA.
# Row 121: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/130/22039/main-image
# Row 122: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/131/24776/restricted
# Row 123: No image found for http://www.metmuseum.org/art/collection/search/132. Setting to NA.
# Row 124: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/133/30893/restricted
# Row 125: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/134/48727/main-image
# Row 126: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/137/2186042/main-image
# Row 127: No image found for http://www.metmuseum.org/art/collection/search/138. Setting to NA.
# Row 128: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/139/30490/main-image
# Row 129: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/140/49480/main-image
# Row 130: No image found for http://www.metmuseum.org/art/collection/search/141. Setting to NA.
# Row 131: No image found for http://www.metmuseum.org/art/collection/search/142. Setting to NA.
# Row 132: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/143/2349/main-image
# Row 133: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/145/2355/main-image
# Row 134: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/146/40152/main-image
# Skipping row 120: No valid image link for Object ID 129.
# Downloaded image for Object ID 130 to /Users/zoeungvari/databases/met_images/130.jpg
# Downloaded image for Object ID 131 to /Users/zoeungvari/databases/met_images/131.jpg
# Skipping row 123: No valid image link for Object ID 132.
# Downloaded image for Object ID 133 to /Users/zoeungvari/databases/met_images/133.jpg
# Downloaded image for Object ID 134 to /Users/zoeungvari/databases/met_images/134.jpg
# Downloaded image for Object ID 137 to /Users/zoeungvari/databases/met_images/137.jpg
# Skipping row 127: No valid image link for Object ID 138.
# Downloaded image for Object ID 139 to /Users/zoeungvari/databases/met_images/139.jpg
# Downloaded image for Object ID 140 to /Users/zoeungvari/databases/met_images/140.jpg
# Skipping row 130: No valid image link for Object ID 141.
# Skipping row 131: No valid image link for Object ID 142.
# Downloaded image for Object ID 143 to /Users/zoeungvari/databases/met_images/143.jpg
# Downloaded image for Object ID 145 to /Users/zoeungvari/databases/met_images/145.jpg
# Downloaded image for Object ID 146 to /Users/zoeungvari/databases/met_images/146.jpg
# Updated the complete Parquet file: complete_data.parquet
# Batch 120 to 134 complete. Sleeping for 3.72 seconds...
#
# Processing rows 135 to 149...
# Row 135: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/147/44922/main-image
# Row 136: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/148/40317/main-image
# Row 137: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/150/11911/restricted
# Row 138: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/151/40157/main-image
# Row 139: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/154/40164/main-image
# Row 140: No image found for http://www.metmuseum.org/art/collection/search/165. Setting to NA.
# Row 141: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/166/2410/main-image
# Row 142: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/170/2407/main-image
# Row 143: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/171/2658/main-image
# Row 144: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/172/40160/main-image
# Row 145: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/173/40316/main-image
# Row 146: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/174/44691/main-image
# Row 147: No image found for http://www.metmuseum.org/art/collection/search/176. Setting to NA.
# Row 148: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/177/4514/main-image
# Row 149: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/179/40182/main-image
# Downloaded image for Object ID 147 to /Users/zoeungvari/databases/met_images/147.jpg
# Downloaded image for Object ID 148 to /Users/zoeungvari/databases/met_images/148.jpg
# Downloaded image for Object ID 150 to /Users/zoeungvari/databases/met_images/150.jpg
# Downloaded image for Object ID 151 to /Users/zoeungvari/databases/met_images/151.jpg
# Downloaded image for Object ID 154 to /Users/zoeungvari/databases/met_images/154.jpg
# Skipping row 140: No valid image link for Object ID 165.
# Downloaded image for Object ID 166 to /Users/zoeungvari/databases/met_images/166.jpg
# Downloaded image for Object ID 170 to /Users/zoeungvari/databases/met_images/170.jpg
# Downloaded image for Object ID 171 to /Users/zoeungvari/databases/met_images/171.jpg
# Downloaded image for Object ID 172 to /Users/zoeungvari/databases/met_images/172.jpg
# Downloaded image for Object ID 173 to /Users/zoeungvari/databases/met_images/173.jpg
# Downloaded image for Object ID 174 to /Users/zoeungvari/databases/met_images/174.jpg
# Skipping row 147: No valid image link for Object ID 176.
# Downloaded image for Object ID 177 to /Users/zoeungvari/databases/met_images/177.jpg
# Downloaded image for Object ID 179 to /Users/zoeungvari/databases/met_images/179.jpg
# Updated the complete Parquet file: complete_data.parquet
# Batch 135 to 149 complete. Sleeping for 1.41 seconds...
#
# Processing rows 150 to 164...
# Row 150: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/180/5047/main-image
# Row 151: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/182/30717/main-image
# Row 152: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/183/27688/main-image
# Row 153: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/184/24322/main-image
# Row 154: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/185/5712/main-image
# Row 155: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/186/40187/main-image
# Row 156: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/187/26335/main-image
# Row 157: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/188/7521/main-image
# Row 158: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/189/7522/main-image
# Row 159: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/190/7665/main-image
# Row 160: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/191/8705/main-image
# Row 161: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/192/9816/main-image
# Row 162: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/193/40092/main-image
# Row 163: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/194/39003/restricted
# Row 164: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/195/18789/main-image
# Downloaded image for Object ID 180 to /Users/zoeungvari/databases/met_images/180.jpg
# Downloaded image for Object ID 182 to /Users/zoeungvari/databases/met_images/182.jpg
# Downloaded image for Object ID 183 to /Users/zoeungvari/databases/met_images/183.jpg
# Downloaded image for Object ID 184 to /Users/zoeungvari/databases/met_images/184.jpg
# Downloaded image for Object ID 185 to /Users/zoeungvari/databases/met_images/185.jpg
# Downloaded image for Object ID 186 to /Users/zoeungvari/databases/met_images/186.jpg
# Downloaded image for Object ID 187 to /Users/zoeungvari/databases/met_images/187.jpg
# Downloaded image for Object ID 188 to /Users/zoeungvari/databases/met_images/188.jpg
# Downloaded image for Object ID 189 to /Users/zoeungvari/databases/met_images/189.jpg
# Downloaded image for Object ID 190 to /Users/zoeungvari/databases/met_images/190.jpg
# Downloaded image for Object ID 191 to /Users/zoeungvari/databases/met_images/191.jpg
# Downloaded image for Object ID 192 to /Users/zoeungvari/databases/met_images/192.jpg
# Downloaded image for Object ID 193 to /Users/zoeungvari/databases/met_images/193.jpg
# Downloaded image for Object ID 194 to /Users/zoeungvari/databases/met_images/194.jpg
# Downloaded image for Object ID 195 to /Users/zoeungvari/databases/met_images/195.jpg
# Updated the complete Parquet file: complete_data.parquet
# Batch 150 to 164 complete. Sleeping for 4.23 seconds...
#
# Processing rows 165 to 179...
# Row 165: No image found for http://www.metmuseum.org/art/collection/search/198. Setting to NA.
# Row 166: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/199/18868/main-image
# Row 167: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/200/33441/main-image
# Row 168: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/201/40150/main-image
# Row 169: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/202/40151/main-image
# Row 170: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/203/49607/main-image
# Row 171: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/204/19585/main-image
# Row 172: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/205/34191/main-image
# Row 173: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/206/14282/restricted
# Row 174: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/208/40165/main-image
# Row 175: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/209/21165/main-image
# Row 176: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/211/21341/main-image
# Row 177: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/212/2176889/main-image
# Row 178: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/213/28230/main-image
# Row 179: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/214/36062/main-image
# Skipping row 165: No valid image link for Object ID 198.
# Downloaded image for Object ID 199 to /Users/zoeungvari/databases/met_images/199.jpg
# Downloaded image for Object ID 200 to /Users/zoeungvari/databases/met_images/200.jpg
# Downloaded image for Object ID 201 to /Users/zoeungvari/databases/met_images/201.jpg
# Downloaded image for Object ID 202 to /Users/zoeungvari/databases/met_images/202.jpg
# Downloaded image for Object ID 203 to /Users/zoeungvari/databases/met_images/203.jpg
# Downloaded image for Object ID 204 to /Users/zoeungvari/databases/met_images/204.jpg
# Downloaded image for Object ID 205 to /Users/zoeungvari/databases/met_images/205.jpg
# Downloaded image for Object ID 206 to /Users/zoeungvari/databases/met_images/206.jpg
# Downloaded image for Object ID 208 to /Users/zoeungvari/databases/met_images/208.jpg
# Downloaded image for Object ID 209 to /Users/zoeungvari/databases/met_images/209.jpg
# Downloaded image for Object ID 211 to /Users/zoeungvari/databases/met_images/211.jpg
# Downloaded image for Object ID 212 to /Users/zoeungvari/databases/met_images/212.jpg
# Downloaded image for Object ID 213 to /Users/zoeungvari/databases/met_images/213.jpg
# Downloaded image for Object ID 214 to /Users/zoeungvari/databases/met_images/214.jpg
# Updated the complete Parquet file: complete_data.parquet
# Batch 165 to 179 complete. Sleeping for 4.48 seconds...
#
# Processing rows 180 to 194...
# Row 180: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/215/19016/main-image
# Row 181: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/216/29432/main-image
# Row 182: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/218/10834/main-image
# Row 183: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/219/23569/main-image
# Row 184: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/220/2176409/main-image
# Row 185: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/221/20886/main-image
# Row 186: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/222/21169/restricted
# Row 187: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/223/24357/main-image
# Row 188: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/224/24774/main-image
# Row 189: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/225/15516/main-image
# Row 190: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/226/33569/restricted
# Row 191: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/227/46596/main-image
# Row 192: No image found for http://www.metmuseum.org/art/collection/search/228. Setting to NA.
# Row 193: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/229/24361/main-image
# Row 194: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/230/25139/main-image
# Downloaded image for Object ID 215 to /Users/zoeungvari/databases/met_images/215.jpg
# Downloaded image for Object ID 216 to /Users/zoeungvari/databases/met_images/216.jpg
# Downloaded image for Object ID 218 to /Users/zoeungvari/databases/met_images/218.jpg
# Downloaded image for Object ID 219 to /Users/zoeungvari/databases/met_images/219.jpg
# Downloaded image for Object ID 220 to /Users/zoeungvari/databases/met_images/220.jpg
# Downloaded image for Object ID 221 to /Users/zoeungvari/databases/met_images/221.jpg
# Downloaded image for Object ID 222 to /Users/zoeungvari/databases/met_images/222.jpg
# Downloaded image for Object ID 223 to /Users/zoeungvari/databases/met_images/223.jpg
# Downloaded image for Object ID 224 to /Users/zoeungvari/databases/met_images/224.jpg
# Downloaded image for Object ID 225 to /Users/zoeungvari/databases/met_images/225.jpg
# Downloaded image for Object ID 226 to /Users/zoeungvari/databases/met_images/226.jpg
# Downloaded image for Object ID 227 to /Users/zoeungvari/databases/met_images/227.jpg
# Skipping row 192: No valid image link for Object ID 228.
# Downloaded image for Object ID 229 to /Users/zoeungvari/databases/met_images/229.jpg
# Downloaded image for Object ID 230 to /Users/zoeungvari/databases/met_images/230.jpg
# Updated the complete Parquet file: complete_data.parquet
# Batch 180 to 194 complete. Sleeping for 2.40 seconds...
#
# Processing rows 195 to 199...
# Row 195: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/231/2018014/main-image
# Row 196: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/232/20463/main-image
# Row 197: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/233/42938/main-image
# Row 198: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/234/20466/main-image
# Row 199: Found image link: https://collectionapi.metmuseum.org/api/collection/v1/iiif/235/662/main-image
# Downloaded image for Object ID 231 to /Users/zoeungvari/databases/met_images/231.jpg
# Downloaded image for Object ID 232 to /Users/zoeungvari/databases/met_images/232.jpg
# Downloaded image for Object ID 233 to /Users/zoeungvari/databases/met_images/233.jpg
# Downloaded image for Object ID 234 to /Users/zoeungvari/databases/met_images/234.jpg
# Downloaded image for Object ID 235 to /Users/zoeungvari/databases/met_images/235.jpg
# Updated the complete Parquet file: complete_data.parquet
# Batch 195 to 199 complete. Sleeping for 4.00 seconds...
